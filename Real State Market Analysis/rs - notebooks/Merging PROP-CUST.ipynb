# %%
import pandas as pd

# %%
dfcust = pd.read_csv('dfcust_cleaned.csv').copy()
dfprop = pd.read_csv('dfprop_cleaned2.csv').copy()

# %%
dfcust.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         162 non-null    int64
#  1   customerid         162 non-null    str
#  2   full_name          162 non-null    str
#  3   age                162 non-null    int64
#  4   entity             162 non-null    int64
#  5   sex                162 non-null    str
#  6   country            162 non-null    int64
#  7   state              162 non-null    int64
#  8   purpose            162 non-null    int64
#  9   deal_satisfaction  162 non-null    int64
#  10  mortgage           162 non-null    int64
#  11  source             162 non-null    str
# dtypes: int64(8), str(4)
# memory usage: 15.3 KB

# %%
dfprop.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  267 non-null    int64
#  1   customerid  195 non-null    str
#  2   id          267 non-null    int64
#  3   building    267 non-null    int64
#  4   date_sale   195 non-null    str
#  5   type        267 non-null    str
#  6   property#   267 non-null    int64
#  7   area        267 non-null    float64
#  8   price       267 non-null    str
#  9   status      267 non-null    int64
# dtypes: float64(1), int64(5), str(4)
# memory usage: 21.0 KB

# %%
dfcust.columns = dfcust.columns.str.strip().str.replace('\ufeff', '')
dfprop.columns = dfprop.columns.str.strip().str.replace('\ufeff', '')

# %%
dfprop = dfprop.drop(columns = ['Unnamed: 0'])
dfprop.head()
# Out:
#   customerid    id  building   date_sale       type  property#     area  \
# 0     C0028   1030         1  2005-11-01  Apartment         30   743.09
# 1     C0027   1029         1  2005-10-01  Apartment         29   756.21
# 2     C0112   2002         2  2007-07-01  Apartment          2   587.28
# 3     C0160   2031         2  2007-12-01  Apartment         31  1604.75
# 4     C0014   1049         1  2004-11-01  Apartment         49  1375.45
#
#           price  status
# 0  $246,172.68        1
# 1  $246,331.90        1
# 2  $209,280.91        1
# 3  $452,667.01        1
# 4  $467,083.31        1

# %%
dfcust = dfcust.drop(columns = ['Unnamed: 0'])
dfcust.head()
# Out:
#   customerid        full_name  age  entity      sex  country  state  purpose  \
# 0      C0110       Kareem Liu   57       1        F        1      1        1
# 1      C0010  Trystan Oconnor   63       1        M        1      1        1
# 2      C0132         Kale Gay   66       1        M        1      1        1
# 3      C0137    Russell Gross   66       1        M        1      1        1
# 4      C0174       Marleez Co   62       0  Unknown        1      1        0
#
#    deal_satisfaction  mortgage   source
# 0                  4         1  Website
# 1                  1         0  Website
# 2                  4         1   Agency
# 3                  5         0  Website
# 4                  5         0  Website

# %%
dfprop['customerid'].to_list()
# Out:
# [' C0028 ',
#  ' C0027 ',
#  ' C0112 ',
#  ' C0160 ',
#  ' C0014 ',
#  ' C0125 ',
#  ' C0125 ',
#  ' C0166 ',
#  ' C0034 ',
#  ' C0170 ',
#  ' C0009 ',
#  ' C0041 ',
#  ' C0057 ',
#  ' C0061 ',
#  ' C0089 ',
#  ' C0159 ',
#  ' C0171 ',
#  ' C0042 ',
#  ' C0093 ',
#  ' C0093 ',
#  ' C0051 ',
#  ' C0064 ',
#  ' C0064 ',
#  ' C0128 ',
#  ' C0019 ',
#  ' C0037 ',
#  ' C0127 ',
#  ' C0018 ',
#  ' C0040 ',
#  ' C0080 ',
#  ' C0083 ',
#  ' C0085 ',
#  ' C0091 ',
#  ' C0007 ',
#  ' C0048 ',
#  ' C0065 ',
#  ' C0096 ',
#  ' C0164 ',
#  ' C0038 ',
#  ' C0087 ',
#  ' C0142 ',
#  ' C0015 ',
#  ' C0122 ',
#  ' C0017 ',
#  ' C0020 ',
#  ' C0086 ',
#  ' C0150 ',
#  ' C0156 ',
#  ' C0169 ',
#  ' C0022 ',
#  ' C0072 ',
#  ' C0136 ',
#  ' C0149 ',
#  ' C0011 ',
#  ' C0073 ',
#  ' C0110 ',
#  ' C0111 ',
#  ' C0123 ',
#  ' C0070 ',
#  ' C0075 ',
#  ' C0076 ',
#  ' C0105 ',
#  ' C0135 ',
#  ' C0153 ',
#  ' C0047 ',
#  ' C0060 ',
#  ' C0066 ',
#  ' C0068 ',
#  ' C0090 ',
#  ' C0095 ',
#  ' C0151 ',
# ...

# %%
dfprop['customerid'] = dfprop['customerid'].str.strip()

# %%
dfmerged = dfcust.merge(dfprop, how = 'outer', on = 'customerid')

# %%
dfmerged['customerid'].duplicated().sum()
# Out:
# np.int64(104)

# %%
dfmerged.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerid         195 non-null    str
#  1   full_name          195 non-null    str
#  2   age                195 non-null    float64
#  3   entity             195 non-null    float64
#  4   sex                195 non-null    str
#  5   country            195 non-null    float64
#  6   state              195 non-null    float64
#  7   purpose            195 non-null    float64
#  8   deal_satisfaction  195 non-null    float64
#  9   mortgage           195 non-null    float64
#  10  source             195 non-null    str
#  11  id                 267 non-null    int64
#  12  building           267 non-null    int64
#  13  date_sale          195 non-null    str
#  14  type               267 non-null    str
#  15  property#          267 non-null    int64
# ...

# %%
dfmerged.tail()
# Out:
#     customerid full_name  age  entity  sex  country  state  purpose  \
# 262        NaN       NaN  NaN     NaN  NaN      NaN    NaN      NaN
# 263        NaN       NaN  NaN     NaN  NaN      NaN    NaN      NaN
# 264        NaN       NaN  NaN     NaN  NaN      NaN    NaN      NaN
# 265        NaN       NaN  NaN     NaN  NaN      NaN    NaN      NaN
# 266        NaN       NaN  NaN     NaN  NaN      NaN    NaN      NaN
#
#      deal_satisfaction  mortgage source    id  building date_sale       type  \
# 262                NaN       NaN    NaN  5044         5       NaN  Apartment
# 263                NaN       NaN    NaN  5047         5       NaN  Apartment
# 264                NaN       NaN    NaN  5048         5       NaN  Apartment
# 265                NaN       NaN    NaN  5050         5       NaN  Apartment
# 266                NaN       NaN    NaN  5051         5       NaN  Apartment
#
#      property#     area         price  status
# 262         44  1238.58  $322,610.74        0
# ...

# %%
dfmerged.to_csv('real-state-data.csv')
